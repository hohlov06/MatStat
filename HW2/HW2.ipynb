# %% [markdown]
# ## Домашнее задание 2 "Основы статистики"

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats 

Number_in_list = 18

# %% [markdown]
# # 2.1
#
# Имеются: выборка $(X_1, ..., X_{100})$, распределение Парето $\alpha > 0 $
#
# $p(x)=\dfrac{\alpha}{x^{\alpha+1}}$, $x > 1$

# %%
def mean_confidence_interval(data, confidence=0.95):
    a = 1.0 * np.array(data)
    n = len(a)
    m, se = np.mean(a), stats.sem(a)
    h = se * stats.t.ppf((1 + confidence) / 2., n-1)
    return m-h, m, m+h

# %%
alphaArray = np.linspace(0.01, 4.99, 100)
leftArray = []
rightArray = []
centralArray = []

for alpha in alphaArray:
    r = stats.pareto.rvs(alpha, size=100)
    left,central, right = mean_confidence_interval(r)
    leftArray.append(left)
    rightArray.append(right)
    centralArray.append(central)
# Out:
# c:\dev\python372\lib\site-packages\scipy\stats\_continuous_distns.py:5366: RuntimeWarning: overflow encountered in power
#   return pow(1-q, -1.0/b)
# c:\dev\python372\lib\site-packages\numpy\core\_methods.py:117: RuntimeWarning: invalid value encountered in subtract
#   x = asanyarray(arr - arrmean)

# %%
plt.figure(figsize=(10, 6))

plt.semilogy(alphaArray, leftArray,label="left stat")
plt.xlabel("alpha")
plt.ylabel("stat")
plt.legend()
plt.show()

plt.figure(figsize=(10, 6))

plt.semilogy(alphaArray, rightArray, label= "right stat")
plt.xlabel("alpha")
plt.ylabel("stat")
plt.legend()
plt.show()

plt.figure(figsize=(10, 6))

plt.semilogy(alphaArray, np.array(rightArray) - np.array(leftArray), label= "interv")
plt.xlabel("alpha")
plt.ylabel("stat")
plt.legend()
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.plot(alphaArray, leftArray,label="left stat")
plt.plot(alphaArray, rightArray, label= "right stat")
plt.plot(alphaArray,centralArray, label= "stat")
plt.fill_between(alphaArray, leftArray, rightArray, alpha=0.5)
plt.xlabel("alpha")
plt.ylabel("stat")
plt.ylim(-1, 20)
plt.legend()
plt.show()

# %% [markdown]
# Выводы: интеграл матожидания для распеределния Парето расходится

# %% [markdown]
# # 2.3
# $N(\theta,1)$
#
# $p(x) = \dfrac{1}{\sqrt{2\pi}} e^{-\frac{(x-\theta)^2}{2}}$

# %%
Nsize = 100
theta_0 = Number_in_list

k_array = np.linspace(1, 5, 21)

# %%
for theta in [theta_0 * k for k in k_array]:
    sample = stats.norm(theta, 1).rvs(size=Nsize)
    c_alpha = stats.norm(Nsize * theta_0, Nsize).ppf(1 - 0.05)
    print('theta = %d: sample_sum = %.2f, c_alpha = %.2f' % (theta, sample.sum(), c_alpha))
# Out:
# theta = 18: sample_sum = 1780.82, c_alpha = 1964.49
# theta = 21: sample_sum = 2167.88, c_alpha = 1964.49
# theta = 25: sample_sum = 2509.30, c_alpha = 1964.49
# theta = 28: sample_sum = 2862.70, c_alpha = 1964.49
# theta = 32: sample_sum = 3227.66, c_alpha = 1964.49
# theta = 36: sample_sum = 3601.75, c_alpha = 1964.49
# theta = 39: sample_sum = 3961.39, c_alpha = 1964.49
# theta = 43: sample_sum = 4313.72, c_alpha = 1964.49
# theta = 46: sample_sum = 4667.01, c_alpha = 1964.49
# theta = 50: sample_sum = 5058.63, c_alpha = 1964.49
# theta = 54: sample_sum = 5402.56, c_alpha = 1964.49
# theta = 57: sample_sum = 5746.37, c_alpha = 1964.49
# theta = 61: sample_sum = 6099.94, c_alpha = 1964.49
# theta = 64: sample_sum = 6489.08, c_alpha = 1964.49
# theta = 68: sample_sum = 6861.49, c_alpha = 1964.49
# theta = 72: sample_sum = 7206.32, c_alpha = 1964.49
# theta = 75: sample_sum = 7556.66, c_alpha = 1964.49
# theta = 79: sample_sum = 7914.35, c_alpha = 1964.49
# theta = 82: sample_sum = 8281.09, c_alpha = 1964.49
# theta = 86: sample_sum = 8644.67, c_alpha = 1964.49
# theta = 90: sample_sum = 8994.21, c_alpha = 1964.49
